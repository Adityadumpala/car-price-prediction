# %% [markdown]
# # data from cars24

# %%
import selenium
from selenium import webdriver
from selenium.common.exceptions import ElementNotInteractableException,NoSuchElementException
import time
import warnings
warnings.filterwarnings('ignore')

# %%
#connect to web driver
driver=webdriver.Chrome(r'C:\Users\Aditya\OneDrive\Desktop\chromedriver.exe')

url='https://www.cars24.com/'
driver.get(url)

# %%
#selecting location or city 
click_on_location=driver.find_element_by_xpath('/html/body/div[1]/div[6]/div/div/div/div[2]/div[2]/button')

click_on_location.click()

# %%
#selecting hyderabad
hyd=driver.find_element_by_xpath('/html/body/div[1]/div[6]/div/div/div/div[2]/ul/li[7]')
hyd.click()

# %%
#clicking on view_all button
view_cars=driver.find_element_by_xpath('/html/body/div[1]/div[1]/header/div/div[2]/div/span')
view_cars.click()

# %%
#scroll buttom of the page
driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")

# %%
#url
urls=[]

url=driver.find_elements_by_xpath('//a[@class="_9Ue0B"]')

for i in url:
    urls.append(i.get_attribute('href'))

# %%
len(urls)
# Out:
# 161

# %%
urls[3:5]
# Out:
# ['https://www.cars24.com/buy-used-hyundai-verna-2013-cars-hyderabad-1044840362/',
#  'https://www.cars24.com/buy-used-maruti-alto-k10-2015-cars-hyderabad-1049278623/']

# %%
len(transmission)
# Out:
# 161

# %%
#location hyderabad

# %%
price=[]
name=[]
owner=[]
kilometers_driven=[]
fuel_type=[]
history=[]
transmission=[]

for url in urls:
    driver.get(url)
    time.sleep(2)
    try:
        nm = driver.find_element_by_xpath('//h2[@class="_2geSF"]')      # Extracting name from xpath
        name.append(nm.text)
    except NoSuchElementException:
        name.append('-')
        
    #price
    time.sleep(1)
    try:
        prc=driver.find_element_by_xpath('//strong[@class="_2yYvS Wqfj6"]')
        price.append(prc.text)
    except NoSuchElementException:
        price.append('-')
        
    #history
    time.sleep(1)
    try:
        hst=driver.find_element_by_xpath('//ul[@class="_2KO13"]/li[1]/strong')
        history.append(hst.text)
    except NoSuchElementException:
        history.append('-')
    
    #owner
    time.sleep(1)
    try:
        ownr=driver.find_element_by_xpath('//ul[@class="_2KO13"]/li[2]/strong')
        owner.append(ownr.text)
    except NoSuchElementException:
        owner.append('-')
    
    #kilomters driven
    time.sleep(1)
    try:
        klm=driver.find_element_by_xpath('//ul[@class="_2KO13"]/li[3]/strong')
        kilometers_driven.append(klm.text)
    except NoSuchElementException:
        kilometers_driven.append('-')
        
    #fuel type
    time.sleep(1)
    try:
        fl=driver.find_element_by_xpath('//ul[@class="_2KO13"]/li[4]/strong')
        fuel_type.append(fl.text)
    except NoSuchElementException:
        fuel_type.append('-')
    
    #transmission
    time.sleep(1)
    try:
        trsn=driver.find_element_by_xpath('//ul[@class="_2KO13"]/li[6]/strong')
        transmission.append(trsn.text)
    except NoSuchElementException:
        transmission.append('-')

# %%
cars_data=pd.DataFrame({'name':name,'fuel_type':fuel_type,'history':history,'transmission':transmission,'kilometers_driven':kilometers_driven,'owner':owner,'price':price})
cars_data
# Out:
#                                               name fuel_type         history  \
# 0         2016 Ford New Figo 1.5 TITANIUM + MANUAL    Diesel  Non-Accidental
# 1                 2015 Maruti Ciaz VXI PLUS MANUAL    Petrol  Non-Accidental
# 2        2009 Toyota Corolla Altis VL AT AUTOMATIC    Petrol  Non-Accidental
# 3    2013 Hyundai Verna FLUIDIC 1.6 SX CRDI MANUAL    Diesel  Non-Accidental
# 4                  2015 Maruti Alto K10 VXI MANUAL    Petrol  Non-Accidental
# ..                                             ...       ...             ...
# 156                 2016 Maruti Celerio VXI MANUAL    Petrol  Non-Accidental
# 157                   2018 Maruti Dzire VXI MANUAL    Petrol  Non-Accidental
# 158                  2020 Toyota YARIS J MT MANUAL    Petrol  Non-Accidental
# 159       2012 Maruti Swift Dzire VDI BS IV MANUAL    Diesel  Non-Accidental
# 160                2015 Toyota Etios Liva G MANUAL    Petrol  Non-Accidental
#
#     transmission kilometers_driven      owner                   price
# 0         MANUAL         91,231 km  1st Owner  Fixed Price\n₹4,86,299
# 1         MANUAL         92,212 km  2nd Owner  Fixed Price\n₹6,04,199
# 2      AUTOMATIC         95,760 km  2nd Owner  Fixed Price\n₹6,33,799
# 3         MANUAL         49,854 km  1st Owner  Fixed Price\n₹6,01,599
# 4         MANUAL       2,35,016 km  1st Owner  Fixed Price\n₹2,69,299
# ..           ...               ...        ...                     ...
# 156       MANUAL         33,792 km  1st Owner  Fixed Price\n₹3,92,999
# 157       MANUAL         27,786 km  1st Owner  Fixed Price\n₹6,78,799
# 158       MANUAL         19,656 km  1st Owner  Fixed Price\n₹8,74,099
# 159       MANUAL       1,22,198 km  1st Owner  Fixed Price\n₹4,60,599
# 160       MANUAL         78,776 km  1st Owner  Fixed Price\n₹4,28,599
#
# [161 rows x 7 columns]

# %%
cars_data.to_csv('hyd_cars24')

# %% [markdown]
# # location bengalore

# %%
#connect to web driver
driver=webdriver.Chrome(r'C:\Users\Aditya\OneDrive\Desktop\chromedriver.exe')

url='https://www.cars24.com/'
driver.get(url)

# %%
#selecting location or city 
select_manual_location=driver.find_element_by_xpath('/html/body/div[1]/div[6]/div/div/div/div[2]/div[2]/button')

select_manual_location.click()

# %%
#selecting hyderabad
mumbai=driver.find_element_by_xpath('/html/body/div[1]/div[6]/div/div/div/div[2]/ul/li[4]')
mumbai.click()

# %%
#clicking on view_all button
view_cars=driver.find_element_by_xpath('/html/body/div[1]/div[1]/header/div/div[2]/div/span')
view_cars.click()

# %%
#scroll buttom of the page
driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
time.sleep(3)

# %%
#url
urls2=[]

url=driver.find_elements_by_xpath('//a[@class="_9Ue0B"]')

for i in url:
    urls2.append(i.get_attribute('href'))

# %%
len(urls2)
# Out:
# 699

# %%
len(variant)
# Out:
# 699

# %%
price=[]
name=[]
owner=[]
kilometers_driven=[]
fuel_type=[]
history=[]
transmission=[]
variant=[]

for url in urls2:
    driver.get(url)
    time.sleep(1)
    try:
        nm = driver.find_element_by_xpath('//h2[@class="_2geSF"]')      # Extracting name from xpath
        name.append(nm.text)
    except NoSuchElementException:
        name.append('-')
        
    #price
    time.sleep(0.5)
    try:
        prc=driver.find_element_by_xpath('//strong[@class="_2yYvS Wqfj6"]')
        price.append(prc.text)
    except NoSuchElementException:
        price.append('-')
        
    time.sleep(0.5)
    try:
        varnt = driver.find_element_by_xpath('//span[@class="_18vo2"]')     # Extracting variant from xpath
        variant.append(varnt.text)
    except NoSuchElementException:
        variant.append('-')
        
    #history
    time.sleep(0.5)
    try:
        hst=driver.find_element_by_xpath('//ul[@class="_2KO13"]/li[1]/strong')
        history.append(hst.text)
    except NoSuchElementException:
        history.append('-')
    
    #owner
    time.sleep(0.5)
    try:
        ownr=driver.find_element_by_xpath('//ul[@class="_2KO13"]/li[2]/strong')
        owner.append(ownr.text)
    except NoSuchElementException:
        owner.append('-')
    
    #kilomters driven
    time.sleep(0.5)
    try:
        klm=driver.find_element_by_xpath('//ul[@class="_2KO13"]/li[3]/strong')
        kilometers_driven.append(klm.text)
    except NoSuchElementException:
        kilometers_driven.append('-')
        
    #fuel type
    time.sleep(0.5)
    try:
        fl=driver.find_element_by_xpath('//ul[@class="_2KO13"]/li[4]/strong')
        fuel_type.append(fl.text)
    except NoSuchElementException:
        fuel_type.append('-')
    
    #transmission
    time.sleep(0.5)
    try:
        trsn=driver.find_element_by_xpath('//ul[@class="_2KO13"]/li[6]/strong')
        transmission.append(trsn.text)
    except NoSuchElementException:
        transmission.append('-')

# %%
import pandas as pd
mumbai_cars24=pd.DataFrame({'name':name,'variant':variant,'fuel_type':fuel_type,'history':history,'kilometers_driven':kilometers_driven,'transmission':transmission,'owner':owner,'price':price})
mumbai_cars24
# Out:
#                                                   name  \
# 0               2014 Honda Amaze 1.2 SMT I VTEC MANUAL
# 1               2019 Honda Amaze 1.2 SMT I VTEC MANUAL
# 2                  2019 Maruti Dzire VXI AMT AUTOMATIC
# 3              2019 Honda Amaze VX AT I DTEC AUTOMATIC
# 4    2017 Ford Ecosport 1.5 TITANIUM TI VCT AT AUTO...
# ..                                                 ...
# 694                    2019 Maruti Alto K10 VXI MANUAL
# 695                2018 Maruti Alto 800 LXI OPT MANUAL
# 696         2018 Honda BR-V 1.5 i-VTEC V CVT AUTOMATIC
# 697  2011 Mercedes Benz E Class E 250 CDI ELEGANCE ...
# 698               2019 Maruti Vitara Brezza VDI MANUAL
#
#                               variant fuel_type         history  \
# 0               1.2 SMT I VTEC MANUAL    Petrol  Non-Accidental
# 1               1.2 SMT I VTEC MANUAL    Petrol  Non-Accidental
# 2                   VXI AMT AUTOMATIC    Petrol  Non-Accidental
# 3              VX AT I DTEC AUTOMATIC    Diesel  Non-Accidental
# 4    1.5 TITANIUM TI VCT AT AUTOMATIC    Petrol  Non-Accidental
# ..                                ...       ...             ...
# 694                        VXI MANUAL    Petrol  Non-Accidental
# 695                    LXI OPT MANUAL    Petrol  Non-Accidental
# 696        1.5 i-VTEC V CVT AUTOMATIC    Petrol  Non-Accidental
# 697      E 250 CDI ELEGANCE AUTOMATIC    Diesel  Non-Accidental
# 698                        VDI MANUAL    Diesel  Non-Accidental
#
#     kilometers_driven transmission      owner                    price
# 0           53,178 km       MANUAL  1st Owner   Fixed Price\n₹4,13,999
# 1            9,023 km       MANUAL  1st Owner   Fixed Price\n₹6,36,599
# 2           31,248 km    AUTOMATIC  1st Owner   Fixed Price\n₹7,14,299
# 3           24,889 km    AUTOMATIC  2nd Owner   Fixed Price\n₹8,06,699
# 4              402 km    AUTOMATIC  1st Owner   Fixed Price\n₹8,44,999
# ..                ...          ...        ...                      ...
# 694         15,222 km       MANUAL  1st Owner   Fixed Price\n₹3,94,899
# 695         10,608 km       MANUAL  1st Owner   Fixed Price\n₹3,14,399
# 696         21,231 km    AUTOMATIC  1st Owner  Fixed Price\n₹10,09,999
# 697         77,546 km    AUTOMATIC  2nd Owner  Fixed Price\n₹11,28,099
# 698         17,395 km       MANUAL  1st Owner   Fixed Price\n₹8,38,699
#
# [699 rows x 8 columns]

# %%
mumbai_cars24.to_csv('cars24_mumbai')

# %%
data=pd.read_csv('cars24_mumbai')
data.head()
# Out:
#    Unnamed: 0                                               name  \
# 0           0             2014 Honda Amaze 1.2 SMT I VTEC MANUAL
# 1           1             2019 Honda Amaze 1.2 SMT I VTEC MANUAL
# 2           2                2019 Maruti Dzire VXI AMT AUTOMATIC
# 3           3            2019 Honda Amaze VX AT I DTEC AUTOMATIC
# 4           4  2017 Ford Ecosport 1.5 TITANIUM TI VCT AT AUTO...
#
#                             variant fuel_type         history  \
# 0             1.2 SMT I VTEC MANUAL    Petrol  Non-Accidental
# 1             1.2 SMT I VTEC MANUAL    Petrol  Non-Accidental
# 2                 VXI AMT AUTOMATIC    Petrol  Non-Accidental
# 3            VX AT I DTEC AUTOMATIC    Diesel  Non-Accidental
# 4  1.5 TITANIUM TI VCT AT AUTOMATIC    Petrol  Non-Accidental
#
#   kilometers_driven transmission      owner                   price
# 0         53,178 km       MANUAL  1st Owner  Fixed Price\n₹4,13,999
# 1          9,023 km       MANUAL  1st Owner  Fixed Price\n₹6,36,599
# 2         31,248 km    AUTOMATIC  1st Owner  Fixed Price\n₹7,14,299
# 3         24,889 km    AUTOMATIC  2nd Owner  Fixed Price\n₹8,06,699
# 4            402 km    AUTOMATIC  1st Owner  Fixed Price\n₹8,44,999

# %%
#cars from delhi

# %%
#connect to web driver
driver=webdriver.Chrome(r'C:\Users\Aditya\OneDrive\Desktop\chromedriver.exe')

url='https://www.cars24.com/'
driver.get(url)

# %%
#selecting location or city 
select_manual_location=driver.find_element_by_xpath('/html/body/div[1]/div[6]/div/div/div/div[2]/div[2]/button')

select_manual_location.click()

# %%
#selecting delhi location
delhi=driver.find_element_by_xpath('/html/body/div[1]/div[6]/div/div/div/div[2]/ul/li[1]')
delhi.click()

# %%
#clicking on view_all button
view_cars=driver.find_element_by_xpath('/html/body/div[1]/div[1]/header/div/div[2]/div/span')
view_cars.click()

# %%
#scroll buttom of the page
driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
time.sleep(30)

# %%
#url
urls3=[]

url=driver.find_elements_by_xpath('//a[@class="_9Ue0B"]')

for i in url:
    urls3.append(i.get_attribute('href'))

# %%
len(urls3)
# Out:
# 685

# %%
len(price)
# Out:
# 241

# %%
price=[]
name=[]
owner=[]
kilometers_driven=[]
fuel_type=[]
history=[]
transmission=[]
variant=[]

def car24_delhi(clf):
    
    for url in clf:
        driver.get(url)
        time.sleep(1)
        try:
            nm = driver.find_element_by_xpath('//h2[@class="_2geSF"]')      # Extracting name from xpath
            name.append(nm.text)
        except NoSuchElementException:
            name.append('-')        
        #price
        time.sleep(1)
        try:
            prc=driver.find_element_by_xpath('//strong[@class="_2yYvS Wqfj6"]')
            price.append(prc.text)
        except NoSuchElementException:
            price.append('-')
        
        time.sleep(1)
        try:
            varnt = driver.find_element_by_xpath('//span[@class="_18vo2"]')     # Extracting variant from xpath
            variant.append(varnt.text)
        except NoSuchElementException:
            variant.append('-')
        
        #history
        time.sleep(3)
        try:
            hst=driver.find_element_by_xpath('//ul[@class="_2KO13"]/li[1]/strong')
            history.append(hst.text)
        except NoSuchElementException:
            history.append('-')    
        #owner
        time.sleep(1)
        try:
            ownr=driver.find_element_by_xpath('//ul[@class="_2KO13"]/li[2]/strong') 
            owner.append(ownr.text)
        except NoSuchElementException:
            owner.append('-')
        #kilomters driven
        time.sleep(1)
        try:
            klm=driver.find_element_by_xpath('//ul[@class="_2KO13"]/li[3]/strong')
            kilometers_driven.append(klm.text)
        except NoSuchElementException:
            kilometers_driven.append('-')
        #fuel type
        time.sleep(1)
        try:
            fl=driver.find_element_by_xpath('//ul[@class="_2KO13"]/li[4]/strong')
            fuel_type.append(fl.text)
        except NoSuchElementException:
            fuel_type.append('-')
        #transmission
        time.sleep(1)
        try:
            trsn=driver.find_element_by_xpath('//ul[@class="_2KO13"]/li[6]/strong')
            transmission.append(trsn.text)
        except NoSuchElementException:
            transmission.append('-')

# %%
urls3_100=urls3[0:100]
urls3_200=urls3[100:200]
urls3_300=urls3[200:350]
urls3_450=urls3[350:450]

# %%
car24_delhi(urls3_100)

# %%
car24_delhi(urls3_200)

# %%
car24_delhi(urls3_300)

# %%
import pandas as pd
delhi_cars24=pd.DataFrame({'name':name,'variant':variant,'fuel_type':fuel_type,'history':history,'kilometers_driven':kilometers_driven,'transmission':transmission,'owner':owner,'price':price})
delhi_cars24
# Out:
#                                          name                 variant  \
# 0    2014 Mahindra Thar CRDE 4X4 BS IV MANUAL   CRDE 4X4 BS IV MANUAL
# 1    2014 Maruti Swift Dzire VDI BS IV MANUAL        VDI BS IV MANUAL
# 2            2015 Maruti Swift VDI ABS MANUAL          VDI ABS MANUAL
# 3     2013 Hyundai i20 SPORTZ 1.4 CRDI MANUAL  SPORTZ 1.4 CRDI MANUAL
# 4                2014 Maruti Swift VXI MANUAL              VXI MANUAL
# ..                                        ...                     ...
# 431   2019 Maruti Baleno DELTA 1.2 K12 MANUAL    DELTA 1.2 K12 MANUAL
# 432              2013 Maruti Swift VDI MANUAL              VDI MANUAL
# 433             2015 Toyota Etios VX D MANUAL             VX D MANUAL
# 434      2019 Hyundai Creta 1.4 S CRDI MANUAL       1.4 S CRDI MANUAL
# 435      2019 Maruti Vitara Brezza VDI MANUAL              VDI MANUAL
#
#     fuel_type         history kilometers_driven transmission      owner  \
# 0      Diesel  Non-Accidental         68,467 km       MANUAL  1st Owner
# 1      Diesel  Non-Accidental         98,109 km       MANUAL  1st Owner
# 2      Diesel  Non-Accidental         45,785 km       MANUAL  1st Owner
# 3      Diesel  Non-Accidental         64,543 km       MANUAL  1st Owner
# 4      Petrol  Non-Accidental       1,07,946 km       MANUAL  1st Owner
# ..        ...             ...               ...          ...        ...
# 431    Petrol  Non-Accidental         26,019 km       MANUAL  1st Owner
# 432    Diesel  Non-Accidental       1,20,466 km       MANUAL  1st Owner
# 433    Diesel  Non-Accidental         77,766 km       MANUAL  1st Owner
# 434    Diesel  Non-Accidental         70,873 km       MANUAL  1st Owner
# 435    Diesel  Non-Accidental         50,192 km       MANUAL  1st Owner
#
#                        price
# 0     Fixed Price\n₹5,22,599
# 1     Fixed Price\n₹4,16,399
# 2     Fixed Price\n₹4,32,499
# 3     Fixed Price\n₹3,64,899
# 4     Fixed Price\n₹3,92,399
# ..                       ...
# 431   Fixed Price\n₹6,89,199
# 432   Fixed Price\n₹3,04,299
# 433   Fixed Price\n₹4,80,499
# 434  Fixed Price\n₹10,48,699
# 435   Fixed Price\n₹7,57,899
#
# [436 rows x 8 columns]

# %%
car24_delhi(urls3_450)

# %%
len(price) #scrapped 100 records are appended previous lists so we have already dataframe delhi_cars24 i have to add this 100 records of the column to existing dataframe
# Out:
# 536

# %%
delhi_cars24_450=pd.DataFrame({'name':name,'variant':variant,'fuel_type':fuel_type,'history':history,'kilometers_driven':kilometers_driven,'transmission':transmission,'owner':owner,'price':price})
delhi_cars24_450
# Out:
#                                              name                     variant  \
# 0        2014 Mahindra Thar CRDE 4X4 BS IV MANUAL       CRDE 4X4 BS IV MANUAL
# 1        2014 Maruti Swift Dzire VDI BS IV MANUAL            VDI BS IV MANUAL
# 2                2015 Maruti Swift VDI ABS MANUAL              VDI ABS MANUAL
# 3         2013 Hyundai i20 SPORTZ 1.4 CRDI MANUAL      SPORTZ 1.4 CRDI MANUAL
# 4                    2014 Maruti Swift VXI MANUAL                  VXI MANUAL
# ..                                            ...                         ...
# 531          2019 Maruti Vitara Brezza VDI MANUAL                  VDI MANUAL
# 532   2019 Maruti Ciaz ALPHA 1.3 DDIS SHVS MANUAL  ALPHA 1.3 DDIS SHVS MANUAL
# 533       2018 Maruti Baleno DELTA 1.2 K12 MANUAL        DELTA 1.2 K12 MANUAL
# 534  2017 Hyundai Grand i10 Sportz1.2 CRDI MANUAL       Sportz1.2 CRDI MANUAL
# 535                  2013 Maruti Swift VDI MANUAL                  VDI MANUAL
#
#     fuel_type         history kilometers_driven transmission      owner  \
# 0      Diesel  Non-Accidental         68,467 km       MANUAL  1st Owner
# 1      Diesel  Non-Accidental         98,109 km       MANUAL  1st Owner
# 2      Diesel  Non-Accidental         45,785 km       MANUAL  1st Owner
# 3      Diesel  Non-Accidental         64,543 km       MANUAL  1st Owner
# 4      Petrol  Non-Accidental       1,07,946 km       MANUAL  1st Owner
# ..        ...             ...               ...          ...        ...
# 531    Diesel  Non-Accidental         24,494 km       MANUAL  2nd Owner
# 532    Diesel  Non-Accidental         76,026 km       MANUAL  1st Owner
# 533    Petrol  Non-Accidental         23,312 km       MANUAL  3rd Owner
# 534    Diesel  Non-Accidental         48,220 km       MANUAL  1st Owner
# 535    Diesel  Non-Accidental         49,220 km       MANUAL  1st Owner
#
#                       price
# 0    Fixed Price\n₹5,22,599
# 1    Fixed Price\n₹4,16,399
# 2    Fixed Price\n₹4,32,499
# 3    Fixed Price\n₹3,64,899
# 4    Fixed Price\n₹3,92,399
# ..                      ...
# 531  Fixed Price\n₹8,08,499
# 532  Fixed Price\n₹8,71,699
# 533  Fixed Price\n₹5,48,499
# 534  Fixed Price\n₹4,93,399
# 535  Fixed Price\n₹3,48,599
#
# [536 rows x 8 columns]

# %%
#deleting duplicate records

delhi_cars=delhi_cars24_450.drop_duplicates()
len(delhi_cars)
# Out:
# 450

# %%
delhi_cars=delhi_cars.to_csv('delhi_cars24')

# %%
data=pd.read_csv('delhi_cars24')
data
# Out:
#      Unnamed: 0                                          name  \
# 0             0      2014 Mahindra Thar CRDE 4X4 BS IV MANUAL
# 1             1      2014 Maruti Swift Dzire VDI BS IV MANUAL
# 2             2              2015 Maruti Swift VDI ABS MANUAL
# 3             3       2013 Hyundai i20 SPORTZ 1.4 CRDI MANUAL
# 4             4                  2014 Maruti Swift VXI MANUAL
# ..          ...                                           ...
# 445         531          2019 Maruti Vitara Brezza VDI MANUAL
# 446         532   2019 Maruti Ciaz ALPHA 1.3 DDIS SHVS MANUAL
# 447         533       2018 Maruti Baleno DELTA 1.2 K12 MANUAL
# 448         534  2017 Hyundai Grand i10 Sportz1.2 CRDI MANUAL
# 449         535                  2013 Maruti Swift VDI MANUAL
#
#                         variant fuel_type         history kilometers_driven  \
# 0         CRDE 4X4 BS IV MANUAL    Diesel  Non-Accidental         68,467 km
# 1              VDI BS IV MANUAL    Diesel  Non-Accidental         98,109 km
# 2                VDI ABS MANUAL    Diesel  Non-Accidental         45,785 km
# 3        SPORTZ 1.4 CRDI MANUAL    Diesel  Non-Accidental         64,543 km
# 4                    VXI MANUAL    Petrol  Non-Accidental       1,07,946 km
# ..                          ...       ...             ...               ...
# 445                  VDI MANUAL    Diesel  Non-Accidental         24,494 km
# 446  ALPHA 1.3 DDIS SHVS MANUAL    Diesel  Non-Accidental         76,026 km
# 447        DELTA 1.2 K12 MANUAL    Petrol  Non-Accidental         23,312 km
# 448       Sportz1.2 CRDI MANUAL    Diesel  Non-Accidental         48,220 km
# 449                  VDI MANUAL    Diesel  Non-Accidental         49,220 km
#
#     transmission      owner                   price
# 0         MANUAL  1st Owner  Fixed Price\n₹5,22,599
# 1         MANUAL  1st Owner  Fixed Price\n₹4,16,399
# 2         MANUAL  1st Owner  Fixed Price\n₹4,32,499
# 3         MANUAL  1st Owner  Fixed Price\n₹3,64,899
# 4         MANUAL  1st Owner  Fixed Price\n₹3,92,399
# ..           ...        ...                     ...
# 445       MANUAL  2nd Owner  Fixed Price\n₹8,08,499
# 446       MANUAL  1st Owner  Fixed Price\n₹8,71,699
# 447       MANUAL  3rd Owner  Fixed Price\n₹5,48,499
# 448       MANUAL  1st Owner  Fixed Price\n₹4,93,399
# 449       MANUAL  1st Owner  Fixed Price\n₹3,48,599
#
# [450 rows x 9 columns]

# %%
#noida

# %%
#connect to web driver
driver=webdriver.Chrome(r'C:\Users\Aditya\OneDrive\Desktop\chromedriver.exe')

url='https://www.cars24.com/'
driver.get(url)

# %%
#selecting location or city 
select_manual_location=driver.find_element_by_xpath('/html/body/div[1]/div[6]/div/div/div/div[2]/div[2]/button')

select_manual_location.click()

# %%
#selecting delhi location
noida=driver.find_element_by_xpath('/html/body/div[1]/div[6]/div/div/div/div[2]/ul/li[2]')
noida.click()

# %%
#clicking on view_all button
view_cars=driver.find_element_by_xpath('/html/body/div[1]/div[1]/header/div/div[2]/div/span')
view_cars.click()

# %%
#scroll buttom of the page
driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
time.sleep(30)

# %%
#url
urls4=[]

url=driver.find_elements_by_xpath('//a[@class="_9Ue0B"]')

for i in url:
    urls4.append(i.get_attribute('href'))

# %%
len(urls4)
# Out:
# 679

# %%
price=[]
name=[]
owner=[]
kilometers_driven=[]
fuel_type=[]
history=[]
transmission=[]
variant=[]

def car24_noida(clf):
    
    for url in clf:
        driver.get(url)
        time.sleep(1)
        try:
            nm = driver.find_element_by_xpath('//h2[@class="_2geSF"]')      # Extracting name from xpath
            name.append(nm.text)
        except NoSuchElementException:
            name.append('-')        
        #price
        time.sleep(1)
        try:
            prc=driver.find_element_by_xpath('//strong[@class="_2yYvS Wqfj6"]')
            price.append(prc.text)
        except NoSuchElementException:
            price.append('-')
        
        time.sleep(1)
        try:
            varnt = driver.find_element_by_xpath('//span[@class="_18vo2"]')     # Extracting variant from xpath
            variant.append(varnt.text)
        except NoSuchElementException:
            variant.append('-')
        
        #history
        time.sleep(3)
        try:
            hst=driver.find_element_by_xpath('//ul[@class="_2KO13"]/li[1]/strong')
            history.append(hst.text)
        except NoSuchElementException:
            history.append('-')    
        #owner
        time.sleep(1)
        try:
            ownr=driver.find_element_by_xpath('//ul[@class="_2KO13"]/li[2]/strong') 
            owner.append(ownr.text)
        except NoSuchElementException:
            owner.append('-')
        #kilomters driven
        time.sleep(1)
        try:
            klm=driver.find_element_by_xpath('//ul[@class="_2KO13"]/li[3]/strong')
            kilometers_driven.append(klm.text)
        except NoSuchElementException:
            kilometers_driven.append('-')
        #fuel type
        time.sleep(1)
        try:
            fl=driver.find_element_by_xpath('//ul[@class="_2KO13"]/li[4]/strong')
            fuel_type.append(fl.text)
        except NoSuchElementException:
            fuel_type.append('-')
        #transmission
        time.sleep(1)
        try:
            trsn=driver.find_element_by_xpath('//ul[@class="_2KO13"]/li[6]/strong')
            transmission.append(trsn.text)
        except NoSuchElementException:
            transmission.append('-')

# %%
urls4_100=urls4[0:100]
urls4_200=urls4[100:200]
urls4_350=urls4[200:350]
urls4_400=urls4[350:400]
urls4_500=urls4[400:500]

# %%
car24_noida(urls4_100)

# %%
car24_noida(urls4_200)

# %%
car24_noida(urls4_350)

# %%
len(price)
# Out:
# 410

# %%
len(price)#here 50 recrods are have to be added to the data frame
# Out:
# 264

# %%
car24_noida(urls4_400)

# %%
noida_cars24=pd.DataFrame({'name':name,'variant':variant,'fuel_type':fuel_type,'history':history,'kilometers_driven':kilometers_driven,'transmission':transmission,'owner':owner,'price':price})
noida_cars24
# Out:
#                                                  name  \
# 0            2013 Maruti Swift Dzire LDI BS IV MANUAL
# 1            2014 Mahindra Thar CRDE 4X4 BS IV MANUAL
# 2        2013 Toyota Innova 2.5 GX 7 STR BS IV MANUAL
# 3    2015 Ford Figo Aspire 1.5 AMBIENTE DIESEL MANUAL
# 4            2014 Maruti Swift Dzire VDI BS IV MANUAL
# ..                                                ...
# 427                      2013 Maruti Swift VDI MANUAL
# 428           2019 Maruti Baleno DELTA 1.2 K12 MANUAL
# 429                      2013 Maruti Swift VDI MANUAL
# 430                     2015 Toyota Etios VX D MANUAL
# 431              2019 Hyundai Creta 1.4 S CRDI MANUAL
#
#                         variant fuel_type         history kilometers_driven  \
# 0              LDI BS IV MANUAL    Diesel  Non-Accidental         50,328 km
# 1         CRDE 4X4 BS IV MANUAL    Diesel  Non-Accidental         68,467 km
# 2     2.5 GX 7 STR BS IV MANUAL    Diesel  Non-Accidental       1,58,147 km
# 3    1.5 AMBIENTE DIESEL MANUAL    Diesel  Non-Accidental         94,959 km
# 4              VDI BS IV MANUAL    Diesel  Non-Accidental         98,109 km
# ..                          ...       ...             ...               ...
# 427                  VDI MANUAL    Diesel  Non-Accidental         67,231 km
# 428        DELTA 1.2 K12 MANUAL    Petrol  Non-Accidental         26,019 km
# 429                  VDI MANUAL    Diesel  Non-Accidental       1,20,466 km
# 430                 VX D MANUAL    Diesel  Non-Accidental         77,766 km
# 431           1.4 S CRDI MANUAL    Diesel  Non-Accidental         70,873 km
#
#     transmission      owner                    price
# 0         MANUAL  2nd Owner   Fixed Price\n₹3,03,099
# 1         MANUAL  1st Owner   Fixed Price\n₹5,22,599
# 2         MANUAL  1st Owner   Fixed Price\n₹6,20,799
# 3         MANUAL  1st Owner   Fixed Price\n₹3,84,199
# 4         MANUAL  1st Owner   Fixed Price\n₹4,16,399
# ..           ...        ...                      ...
# 427       MANUAL  1st Owner   Fixed Price\n₹3,47,099
# 428       MANUAL  1st Owner   Fixed Price\n₹6,89,199
# 429       MANUAL  1st Owner   Fixed Price\n₹3,04,299
# 430       MANUAL  1st Owner   Fixed Price\n₹4,80,499
# 431       MANUAL  1st Owner  Fixed Price\n₹10,48,699
#
# [432 rows x 8 columns]

# %%
noida_cars=noida_cars24.drop_duplicates()
len(noida_cars)
# Out:
# 409

# %%
noida_cars=noida_cars.to_csv('nida_cars24')

# %%
data=pd.read_csv('nida_cars24')
data
# Out:
#      Unnamed: 0                                              name  \
# 0             0          2013 Maruti Swift Dzire LDI BS IV MANUAL
# 1             1          2014 Mahindra Thar CRDE 4X4 BS IV MANUAL
# 2             2      2013 Toyota Innova 2.5 GX 7 STR BS IV MANUAL
# 3             3  2015 Ford Figo Aspire 1.5 AMBIENTE DIESEL MANUAL
# 4             4          2014 Maruti Swift Dzire VDI BS IV MANUAL
# ..          ...                                               ...
# 404         405                      2013 Maruti Swift VDI MANUAL
# 405         406              2019 Maruti Vitara Brezza VDI MANUAL
# 406         407                    2019 Maruti Celerio VXI MANUAL
# 407         408                      2012 Maruti Swift VDI MANUAL
# 408         409            2018 Maruti Baleno ZETA 1.2 K12 MANUAL
#
#                         variant fuel_type         history kilometers_driven  \
# 0              LDI BS IV MANUAL    Diesel  Non-Accidental         50,328 km
# 1         CRDE 4X4 BS IV MANUAL    Diesel  Non-Accidental         68,467 km
# 2     2.5 GX 7 STR BS IV MANUAL    Diesel  Non-Accidental       1,58,147 km
# 3    1.5 AMBIENTE DIESEL MANUAL    Diesel  Non-Accidental         94,959 km
# 4              VDI BS IV MANUAL    Diesel  Non-Accidental         98,109 km
# ..                          ...       ...             ...               ...
# 404                  VDI MANUAL    Diesel  Non-Accidental       1,22,500 km
# 405                  VDI MANUAL    Diesel  Non-Accidental         37,643 km
# 406                  VXI MANUAL    Petrol  Non-Accidental         35,615 km
# 407                  VDI MANUAL    Diesel  Non-Accidental       1,30,190 km
# 408         ZETA 1.2 K12 MANUAL    Petrol  Non-Accidental         10,308 km
#
#     transmission      owner                   price
# 0         MANUAL  2nd Owner  Fixed Price\n₹3,03,099
# 1         MANUAL  1st Owner  Fixed Price\n₹5,22,599
# 2         MANUAL  1st Owner  Fixed Price\n₹6,20,799
# 3         MANUAL  1st Owner  Fixed Price\n₹3,84,199
# 4         MANUAL  1st Owner  Fixed Price\n₹4,16,399
# ..           ...        ...                     ...
# 404       MANUAL  1st Owner  Fixed Price\n₹3,08,899
# 405       MANUAL  1st Owner  Fixed Price\n₹8,08,499
# 406       MANUAL  1st Owner  Fixed Price\n₹4,73,399
# 407       MANUAL  1st Owner  Fixed Price\n₹2,97,999
# 408       MANUAL  2nd Owner  Fixed Price\n₹6,12,499
#
# [409 rows x 9 columns]

# %%
#chennai

# %%
#connect to web driver
driver=webdriver.Chrome(r'C:\Users\Aditya\OneDrive\Desktop\chromedriver.exe')

url='https://www.cars24.com/'
driver.get(url)

# %%
#selecting location or city 
select_manual_location=driver.find_element_by_xpath('/html/body/div[1]/div[6]/div/div/div/div[2]/div[2]/button')

select_manual_location.click()

# %%
#selecting delhi location
chennai=driver.find_element_by_xpath('/html/body/div[1]/div[6]/div/div/div/div[2]/ul/li[8]')
chennai.click()

# %%
#clicking on view_all button
view_cars=driver.find_element_by_xpath('/html/body/div[1]/div[1]/header/div/div[2]/div/span')
view_cars.click()

# %%
#scroll buttom of the page
driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
time.sleep(30)

# %%
#url
urls5=[]

url=driver.find_elements_by_xpath('//a[@class="_9Ue0B"]')

for i in url:
    urls5.append(i.get_attribute('href'))

# %%
len(urls5)
# Out:
# 560

# %%
price=[]
name=[]
owner=[]
kilometers_driven=[]
fuel_type=[]
history=[]
transmission=[]
variant=[]

def car24_chennai(clf):
    
    for url in clf:
        driver.get(url)
        time.sleep(1)
        try:
            nm = driver.find_element_by_xpath('//h2[@class="_2geSF"]')      # Extracting name from xpath
            name.append(nm.text)
        except NoSuchElementException:
            name.append('-')        
        #price
        time.sleep(1)
        try:
            prc=driver.find_element_by_xpath('//strong[@class="_2yYvS Wqfj6"]')
            price.append(prc.text)
        except NoSuchElementException:
            price.append('-')
        
        time.sleep(1)
        try:
            varnt = driver.find_element_by_xpath('//span[@class="_18vo2"]')     # Extracting variant from xpath
            variant.append(varnt.text)
        except NoSuchElementException:
            variant.append('-')
        
        #history
        time.sleep(3)
        try:
            hst=driver.find_element_by_xpath('//ul[@class="_2KO13"]/li[1]/strong')
            history.append(hst.text)
        except NoSuchElementException:
            history.append('-')    
        #owner
        time.sleep(1)
        try:
            ownr=driver.find_element_by_xpath('//ul[@class="_2KO13"]/li[2]/strong') 
            owner.append(ownr.text)
        except NoSuchElementException:
            owner.append('-')
        #kilomters driven
        time.sleep(1)
        try:
            klm=driver.find_element_by_xpath('//ul[@class="_2KO13"]/li[3]/strong')
            kilometers_driven.append(klm.text)
        except NoSuchElementException:
            kilometers_driven.append('-')
        #fuel type
        time.sleep(1)
        try:
            fl=driver.find_element_by_xpath('//ul[@class="_2KO13"]/li[4]/strong')
            fuel_type.append(fl.text)
        except NoSuchElementException:
            fuel_type.append('-')
        #transmission
        time.sleep(1)
        try:
            trsn=driver.find_element_by_xpath('//ul[@class="_2KO13"]/li[6]/strong')
            transmission.append(trsn.text)
        except NoSuchElementException:
            transmission.append('-')

# %%
car24_chennai(urls5)

# %%
len(price)
# Out:
# 560

# %%
import pandas as pd
chennai_cars24=pd.DataFrame({'name':name,'variant':variant,'fuel_type':fuel_type,'history':history,'kilometers_driven':kilometers_driven,'transmission':transmission,'owner':owner,'price':price})
chennai_cars24
# Out:
#                                                  name  \
# 0            2019 Renault Kwid 1.0 CLIMBER OPT MANUAL
# 1       2019 Maruti Eeco 5 STR WITH AC PLUSHTR MANUAL
# 2     2014 Nissan Terrano XL PLUS 85 PS DEISEL MANUAL
# 3    2018 Ford Figo Aspire 1.2 TITANIUM PETROL MANUAL
# 4                  2016 Maruti Ertiga VDI SHVS MANUAL
# ..                                                ...
# 555  2018 Hyundai NEW SANTRO 1.1 SPORTS AMT AUTOMATIC
# 556  2018 Hyundai NEW SANTRO 1.1 SPORTS AMT AUTOMATIC
# 557            2018 Tata Tiago XT 1.2 REVOTRON MANUAL
# 558        2018 Ford Ecosport 1.5TITANIUM TDCI MANUAL
# 559                      2019 Maruti Swift LXI MANUAL
#
#                           variant fuel_type         history kilometers_driven  \
# 0          1.0 CLIMBER OPT MANUAL    Petrol  Non-Accidental         24,291 km
# 1    5 STR WITH AC PLUSHTR MANUAL    Petrol  Non-Accidental          1,186 km
# 2     XL PLUS 85 PS DEISEL MANUAL    Diesel  Non-Accidental       1,96,061 km
# 3      1.2 TITANIUM PETROL MANUAL    Petrol  Non-Accidental         20,539 km
# 4                 VDI SHVS MANUAL    Diesel  Non-Accidental         86,671 km
# ..                            ...       ...             ...               ...
# 555      1.1 SPORTS AMT AUTOMATIC    Petrol  Non-Accidental          9,920 km
# 556      1.1 SPORTS AMT AUTOMATIC    Petrol  Non-Accidental         18,501 km
# 557        XT 1.2 REVOTRON MANUAL    Petrol  Non-Accidental         23,813 km
# 558       1.5TITANIUM TDCI MANUAL    Diesel  Non-Accidental         38,617 km
# 559                    LXI MANUAL    Petrol  Non-Accidental         10,412 km
#
#     transmission      owner                   price
# 0         MANUAL  1st Owner  Fixed Price\n₹4,72,699
# 1         MANUAL  1st Owner  Fixed Price\n₹4,93,899
# 2         MANUAL  1st Owner  Fixed Price\n₹4,75,699
# 3         MANUAL  1st Owner  Fixed Price\n₹6,01,499
# 4         MANUAL  1st Owner  Fixed Price\n₹7,55,199
# ..           ...        ...                     ...
# 555    AUTOMATIC  1st Owner  Fixed Price\n₹5,70,799
# 556    AUTOMATIC  1st Owner  Fixed Price\n₹5,44,299
# 557       MANUAL  1st Owner  Fixed Price\n₹4,76,299
# 558       MANUAL  1st Owner  Fixed Price\n₹8,21,499
# 559       MANUAL  1st Owner  Fixed Price\n₹5,89,299
#
# [560 rows x 8 columns]

# %%
chennai_cars24=chennai_cars24.to_csv('cars24_chennai')

# %%
data=pd.read_csv('cars24_chennai')
data.head()
# Out:
#    Unnamed: 0                                              name  \
# 0           0          2019 Renault Kwid 1.0 CLIMBER OPT MANUAL
# 1           1     2019 Maruti Eeco 5 STR WITH AC PLUSHTR MANUAL
# 2           2   2014 Nissan Terrano XL PLUS 85 PS DEISEL MANUAL
# 3           3  2018 Ford Figo Aspire 1.2 TITANIUM PETROL MANUAL
# 4           4                2016 Maruti Ertiga VDI SHVS MANUAL
#
#                         variant fuel_type         history kilometers_driven  \
# 0        1.0 CLIMBER OPT MANUAL    Petrol  Non-Accidental         24,291 km
# 1  5 STR WITH AC PLUSHTR MANUAL    Petrol  Non-Accidental          1,186 km
# 2   XL PLUS 85 PS DEISEL MANUAL    Diesel  Non-Accidental       1,96,061 km
# 3    1.2 TITANIUM PETROL MANUAL    Petrol  Non-Accidental         20,539 km
# 4               VDI SHVS MANUAL    Diesel  Non-Accidental         86,671 km
#
#   transmission      owner                   price
# 0       MANUAL  1st Owner  Fixed Price\n₹4,72,699
# 1       MANUAL  1st Owner  Fixed Price\n₹4,93,899
# 2       MANUAL  1st Owner  Fixed Price\n₹4,75,699
# 3       MANUAL  1st Owner  Fixed Price\n₹6,01,499
# 4       MANUAL  1st Owner  Fixed Price\n₹7,55,199

# %%
#cars from olx

# %%
#connect to web driver
driver=webdriver.Chrome(r'C:\Users\Aditya\OneDrive\Desktop\chromedriver.exe')

url='https://www.olx.in/'
driver.get(url)

# %%
#clicking on cars
click_on_cars=driver.find_element_by_xpath('//div[@class="_3AGJR _18NX_"]')
click_on_cars.click()

# %%
#click on load more button 
while True:
    try:
        btn=driver.find_element_by_xpath('//button[@class="rui-39-wj rui-3evoE rui-1JPTg"]')
        btn.click()
        time.sleep(2)
    except NoSuchElementException:break

# %%
#url
urls4=[]

url=driver.find_elements_by_xpath('//li[@class="_31j8e"]/a[1]')

for i in url:
    urls4.append(i.get_attribute('href'))

# %%
len(urls4)
# Out:
# 500

# %%
price=[]
name=[]
owner=[]
kilometers_driven=[]
fuel_type=[]
transmission=[]
variant=[]

def cars_olx(clf):
    
    for url in clf:
        driver.get(url)
        time.sleep(1)
        try:
            nm = driver.find_element_by_xpath('//div[@class="_35xN1"]')      # Extracting name from xpath
            name.append(nm.text)
        except NoSuchElementException:
            name.append('-')        
        #price
        time.sleep(1)
        try:
            prc=driver.find_element_by_xpath('//div[@class="_3FkyT"]')
            price.append(prc.text)
        except NoSuchElementException:
            price.append('-')
       #variant
    
        time.sleep(1)
        try:
            varnt = driver.find_element_by_xpath('//div[@class="_3tLee"]')     # Extracting variant from xpath
            variant.append(varnt.text)
        except NoSuchElementException:
            variant.append('-')

        #owner
        time.sleep(1)
        try:
            ownr=driver.find_element_by_xpath('//div[@class="_1idEV"]/div[2]') 
            owner.append(ownr.text)
        except NoSuchElementException:
            owner.append('-')
        #kilomters driven
        time.sleep(1)
        try:
            klm=driver.find_element_by_xpath('//div[@class="aOxkz"]/div[2]')
            kilometers_driven.append(klm.text)
        except NoSuchElementException:
            kilometers_driven.append('-')
        #fuel type
        time.sleep(1)
        try:
            fl=driver.find_element_by_xpath('//div[@class="aOxkz"]/div[1]')
            fuel_type.append(fl.text)
        except NoSuchElementException:
            fuel_type.append('-')
        #transmission
        time.sleep(1)
        try:
            trsn=driver.find_element_by_xpath('//div[@class="aOxkz"]/div[3]')
            transmission.append(trsn.text)
        except NoSuchElementException:
            transmission.append('-')

# %%
urls4_100=urls4[0:100]
urls4_200=urls4[100:200]

# %%
cars_olx(urls4_100)

# %%
cars_olx(urls4_200)

# %%
len(name)
# Out:
# 308

# %%
name=name[0:307]

# %%
len(name)
# Out:
# 307

# %%
import pandas as pd
car_olx=pd.DataFrame({'name':name,'owner':owner,'fuel_type':fuel_type,'transmission':transmission,'variant':variant,'kilometers_driven':kilometers_driven,'price':price})
car_olx
# Out:
#                                    name  owner fuel_type transmission  \
# 0    Maruti Suzuki Vitara Brezza (2016)    1st    DIESEL       MANUAL
# 1           Toyota Innova Crysta (2018)    1st    DIESEL       MANUAL
# 2                     Honda City (2010)    1st    PETROL       MANUAL
# 3             Maruti Suzuki Ritz (2016)  Third    PETROL       MANUAL
# 4                 Hyundai Accent (2006)  First    PETROL       MANUAL
# ..                                  ...    ...       ...          ...
# 302                Toyota Innova (2013)     --    DIESEL       MANUAL
# 303            Hyundai Grand I10 (2013)    2nd    PETROL       MANUAL
# 304                Hyundai Venue (2020)    1st    PETROL       MANUAL
# 305                  Hyundai I20 (2021)    1st    DIESEL    AUTOMATIC
# 306              Mahindra Xuv500 (2019)    2nd    PETROL    AUTOMATIC
#
#                 variant kilometers_driven        price
# 0    ZDi Plus Dual Tone        52000.0 KM   ₹ 6,99,999
# 1                 2.4 V        38000.0 KM  ₹ 21,50,000
# 2    2008-2011 1.5 E MT        79521.0 KM   ₹ 4,10,000
# 3                   LXi         200000 KM   ₹ 2,10,000
# 4                Others          90000 KM   ₹ 1,40,000
# ..                  ...               ...          ...
# 302      1.2 CRDi Magna        73000.0 KM   ₹ 2,39,000
# 303       SX Option iMT        13500.0 KM  ₹ 10,00,000
# 304  Asta 1.0 Turbo iMT        17700.0 KM   ₹ 9,50,000
# 305       W11 Option AT        12650.0 KM  ₹ 19,00,000
# 306           E 200 CGI        79000.0 KM  ₹ 11,00,000
#
# [307 rows x 7 columns]

# %%
car_olx1=car_olx.drop_duplicates()
len(car_olx1)
# Out:
# 307

# %%
car_olx1.to_csv('olx_cars')

# %%
data=pd.read_csv('olx_cars')
data
# Out:
#      Unnamed: 0                                name  owner fuel_type  \
# 0             0  Maruti Suzuki Vitara Brezza (2016)    1st    DIESEL
# 1             1         Toyota Innova Crysta (2018)    1st    DIESEL
# 2             2                   Honda City (2010)    1st    PETROL
# 3             3           Maruti Suzuki Ritz (2016)  Third    PETROL
# 4             4               Hyundai Accent (2006)  First    PETROL
# ..          ...                                 ...    ...       ...
# 302         302                Toyota Innova (2013)     --    DIESEL
# 303         303            Hyundai Grand I10 (2013)    2nd    PETROL
# 304         304                Hyundai Venue (2020)    1st    PETROL
# 305         305                  Hyundai I20 (2021)    1st    DIESEL
# 306         306              Mahindra Xuv500 (2019)    2nd    PETROL
#
#     transmission             variant kilometers_driven        price
# 0         MANUAL  ZDi Plus Dual Tone        52000.0 KM   ₹ 6,99,999
# 1         MANUAL               2.4 V        38000.0 KM  ₹ 21,50,000
# 2         MANUAL  2008-2011 1.5 E MT        79521.0 KM   ₹ 4,10,000
# 3         MANUAL                 LXi         200000 KM   ₹ 2,10,000
# 4         MANUAL              Others          90000 KM   ₹ 1,40,000
# ..           ...                 ...               ...          ...
# 302       MANUAL      1.2 CRDi Magna        73000.0 KM   ₹ 2,39,000
# 303       MANUAL       SX Option iMT        13500.0 KM  ₹ 10,00,000
# 304       MANUAL  Asta 1.0 Turbo iMT        17700.0 KM   ₹ 9,50,000
# 305    AUTOMATIC       W11 Option AT        12650.0 KM  ₹ 19,00,000
# 306    AUTOMATIC           E 200 CGI        79000.0 KM  ₹ 11,00,000
#
# [307 rows x 8 columns]
